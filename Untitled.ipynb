# %%
import pandas as pd

X = pd.read_csv("S21_M4DS_PRJ_03_LinReg_data_X.csv", na_values='NaN').dropna()
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Columns: 498 entries, -0.099362 to Unnamed: 497
# dtypes: float64(498)
# memory usage: 0.0 bytes

# %%
import numpy as np
#from mlxtend.evaluate import bias_variance_decomp

X = pd.read_csv("S21_M4DS_PRJ_03_LinReg_data_X.csv", header = None)

Y = pd.read_csv("S21_M4DS_PRJ_03_LinReg_data_Y.csv",header = None)

# %%
XT=X.dropna(axis='columns')
YT=Y.dropna(axis='columns')

# Set SEED for reproducibility
SEED = 1

# Split the data into 70% train and 30% test
X_train, X_test, Y_train, Y_test = train_test_split(XT, YT, test_size=0.3, random_state=SEED)

# Instantiate a DecisionTreeRegressor dt
dt = DecisionTreeRegressor(max_depth=4, min_samples_leaf=0.26, random_state=SEED)

# Compute the array containing the 10-folds CV MSEs
MSE_CV_scores = - cross_val_score(dt, X_train, Y_train, cv=10, 
                                 scoring='neg_mean_squared_error', n_jobs=-1)

# Compute the 10-folds CV RMSE
RMSE_CV = (MSE_CV_scores.mean()) ** 0.5

# Print RMSE_CV
print('CV RMSE: {:.2f}'.format(RMSE_CV))

# Fit dt to the training set
dt.fit(X_train, Y_train)

# Predict the labels of the training set
Y_pred_train = dt.predict(X_train)

# Evaluate the training set RMSE of dt
RMSE_train = (MSE(Y_train, Y_pred_train)) ** 0.5

# Print RMSE_train
print("Train RMSE: {:.2f}".format(RMSE_train))


# In[5]:


import numpy as np
import matplotlib.pyplot as plt
from random import randint
from math import pi as PI


plt.style.use('ggplot')

X = pd.read_csv("S21_M4DS_PRJ_03_LinReg_data_X.csv", na_values='NaN').dropna()
X.info()

X = pd.read_csv("S21_M4DS_PRJ_03_LinReg_data_X.csv", header = None)

Y = pd.read_csv("S21_M4DS_PRJ_03_LinReg_data_Y.csv",header = None)

Y.info()

XT=X.dropna(axis='columns')
YT=Y.dropna(axis='columns')

print(XT)
print(YT)

# number of observations
NUM_OBS = 500

# predictors
XT = np.linspace(0, 2, num = NUM_OBS)
# noise
eps = np.random.normal(0, 1, NUM_OBS)
# outcome
YT = np.sin(PI*XT) + eps

fig = plt.figure(figsize=(7,7))
ax = plt.axes()
ax.set_title('YT = sin(πx) + Ɛ')
ax.set_xlabel("XT")
ax.set_ylabel("YT")

ax.scatter(XT, YT, c = 'k')

x_train, x_test, y_train, y_test = train_test_split(XT,
                                                    YT,
                                                    test_size = 0.2,
                                                    random_state = 1)

fig = plt.figure(figsize = (7,7))
ax = plt.axes()
ax.set_title('YT = sin(πx) + Ɛ')
ax.set_xlabel("XT")
ax.set_ylabel("YT")

ax.scatter(x_train, y_train, label = "Train set")
ax.scatter(x_test, y_test, label = "Test set")
ax.legend()


# In[71]:


# number of polynomial models to investigate
NUM_MODELS = 25

colors = iter(plt.cm.rainbow(np.linspace(0, 1, NUM_MODELS)))

fig, axs = plt.subplots(2, 2, figsize = (20,20))

axs[0, 0].set_title('Train Set Predictions')
axs[1, 0].set_title('Test Set Predictions')
axs[0, 1].set_title('Train Set MSE')
axs[1, 1].set_title('Test Set MSE')

axs[0, 0].set_xlabel("x train")
axs[0, 0].set_ylabel("YT")
axs[0, 0].set_ylim([-3, 3])

axs[1, 0].set_xlabel("x test")
axs[1, 0].set_ylabel("YT")
axs[1, 0].set_ylim([-3, 3])

axs[0, 1].set_xlabel("polynomial degree")
axs[0, 1].set_ylabel("train MSE")

axs[1, 1].set_xlabel("polynomial degree")
axs[1, 1].set_ylabel("test MSE")

axs[0,0].scatter(x_train, y_train, c = 'k', label = "y train")
axs[1,0].scatter(x_test, y_test, c = 'k', label = "y test")

train_mse = []
test_mse = []

for k in range(0, NUM_MODELS):

  c = next(colors)

  # k-th degree polynomial coefficients
  fit_coeff = np.polyfit(x_train, y_train, deg = k+1)

  # train and test k-th degree polynomial fit
  y_train_pred = np.polyval(fit_coeff, x_train)
  y_test_pred = np.polyval(fit_coeff, x_test)

  # plot train and test k-th degree polynomial fit
  axs[0,0].scatter(x_train,
                   y_train_pred,
                   color = c,
                   label = "deg: {}".format(k+1))
  
  axs[1,0].scatter(x_test,
                   y_test_pred,
                   color = c,
                   label = "deg: {}".format(k+1))

  # train and test MSE of k-th degree polynomial fit 
  iter_train_mse = mean_squared_error(y_train_pred, y_train)
  iter_test_mse = mean_squared_error(y_test_pred, y_test)

  train_mse.append(iter_train_mse)
  test_mse.append(iter_test_mse)

  # plot train and test MSE of k-th degree polynomial fit
  axs[0,1].plot(k+1,
                iter_train_mse,
                color = c,
                label = "deg: {}".format(k+1),
                marker = 'D',
                markersize = 12,
                markeredgecolor = 'black',
                markeredgewidth = 3)
  
  axs[1,1].plot(k+1,
                iter_test_mse,
                color = c,
                label = "deg: {}".format(k+1),
                marker = 'D',
                markersize = 12,
                markeredgecolor = 'black',
                markeredgewidth = 3)

# plot dashed line to interpolate MSE measures
axs[0,1].plot(range(1,NUM_MODELS+1), train_mse, 'k--')
axs[1,1].plot(range(1,NUM_MODELS+1), test_mse, 'k--')

# draw legends
axs[0,1].legend(loc = "upper right",
                bbox_to_anchor = (1.2, 1.01),
                prop = {'size': 12})
axs[1,1].legend(loc = "upper right",
                bbox_to_anchor = (1.2, 1.01),
                prop = {'size': 12})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7fe1f7f54ed3> in <module>
#       6
#       7 # Split the data into 70% train and 30% test
# ----> 8 X_train, X_test, Y_train, Y_test = train_test_split(XT, YT, test_size=0.3, random_state=SEED)
#       9
#      10 # Instantiate a DecisionTreeRegressor dt
#
# NameError: name 'train_test_split' is not defined

# %%
print("Best fit polynomial degree: ", test_mse.index(min(test_mse)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-074956590c4a> in <module>
# ----> 1 print("Best fit polynomial degree: ", test_mse.index(min(test_mse)))
#
# NameError: name 'test_mse' is not defined
